# %%
# question 1 

name = input("Enter your name: ")
age = int(input("Enter your age: "))
print(f"Hello {name}, you're {age} years old.")
# Out:
# Hello Negi, you're 24 years old.

# %%
# question 2 

num1 = int(input("Enter a number: "))
num2 = int(input("Enter another number: "))
sum = num1 + num2
diff = num1 - num2 
pdt = num1 * num2 
quotient = num1 / num2

print(sum, diff, pdt, quotient)
# Out:
# 6 -2 8 0.5

# %%
# question 3 
a = 1
b = 2 
c = 3.0

avg = (a+b+c)/3
print(avg)
# Out:
# 2.0

# %%
# question 4
val = "45"
int_val = int(val)
float_val = float(val)
strin_val = str(float_val)
print(int_val, type(int_val))
print(float_val, type(float_val))
print(strin_val, type(strin_val))
# Out:
# 45 <class 'int'>
# 45.0 <class 'float'>
# 45.0 <class 'str'>

# %%
# question 5
x = 10 + 3 * 2 ** 2
print(x)
# Out:
# 22

# %%
# question 6 
a = 1
b = 2

print("Before Swap", a , b)
c = a 
a = b
b = c

print("After Swap", a , b)

print("Before Swap", a , b)
a = a + b  
b = a - b  
a = a - b 
 
print("After Swap", a , b)
# Out:
# Before Swap 1 2
# After Swap 2 1

# %%
# question 7 
def conversion(val):
    conv = (float(val) * (9/5)) + 32
    return str(conv)

temp = input("Enter the temperature : ")
print(conversion(temp))
# Out:
# 212.0

# %%
# question 8 

def area_circle(radius):
    area = 3.14 * (radius ** 2)
    return area

radius = float(input("Enter the radius :"))
print("Area of circle: ", area_circle(radius))
# Out:
# Area of circle:  31400.0

# %%
# question 9 
def interest(p,r,t):
    interest = (float(p)*float(r)*float(t))/100
    return interest

p = "21000"
r = 20
t = 1.5

print(interest(p,r,t))
# Out:
# 6300.0

# %%
# question 10 
num = 45.78
int_part = int(num)
decimal_part = num % int_part

print(int_part, decimal_part)
# Out:
# 45 0.7800000000000011
