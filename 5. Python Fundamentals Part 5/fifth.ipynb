# %%
try:
    x = int(input())
    y = 10/x
except ZeroDivisionError:
    print("You cannot divide by zero!")
else:
    print(x)
finally:
    print("Execution completed.")
# Out:
# 2131
# Execution completed.

# %% [markdown]
# ## Problem Sets

# %%
#q1 

with open("sample.txt", "w") as df:
    df.write("Pawan\n")
    df.write("Akash\n")
    df.write("Utkarsh\n")
    df.write("Chhavi\n")
    df.write("Nishthaa\n")
    print(df)

with open("sample.txt", "r") as df:
    print(df.readlines())
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='w' encoding='UTF-8'>
# ['Pawan\n', 'Akash\n', 'Utkarsh\n', 'Chhavi\n', 'Nishthaa\n']

# %%
#q2
with open("log.txt", "a") as f:
    f.write("Prgram ran nicely")

with open("log.txt","r") as f:
    print(f.readlines())
# Out:
# ['Prgram ran nicelyPrgram ran nicely']

# %%
#q3
multiple_5 = [x for x in range(26) if x % 5 == 0]
greater_15 = [x for x in multiple_5 if x > 15]
print(multiple_5)
print(greater_15)
# Out:
# [0, 5, 10, 15, 20, 25]
# [20, 25]

# %%
#q4
import json

dic = {
    "Delhi" : 100_000,
    "Rishikesh" : 10_000,
    "Bengluru" : 50_000
}

json_string = json.dumps(dic)
with open("raw.json", "w") as f: 
    json.dump(dic, f)

# %%
with open("raw.json", "r") as f: 
    data = json.load(f)
    print(data)
# Out:
# {'Delhi': 100000, 'Rishikesh': 10000, 'Bengluru': 50000}

# %%
new_city = {"Pune" : 40_000}
dic.update(new_city)

with open("raw.json", "w") as f:
    json.dump(dic, f)

# %%
#q5 

try:
    with open("data.txt", "r") as f:
        data = f.read()
        print(data)
except FileNotFoundError:
    print("File doesn't exist")
# Out:
# File doesn't exist
